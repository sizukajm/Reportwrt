# %%
# !pip install opendatasets
# Out:
# ...
#      -------------------------------------- 63.3/63.3 kB 487.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for kaggle: filename=kaggle-1.5.13-py3-none-any.whl size=77731 sha256=e5fb4873423b8e637c1f0e4135aec46106e7ca77709b1e9cad1dee10ec88a9cb
#   Stored in directory: c:\users\jhili\appdata\local\pip\cache\wheels\1b\22\79\e73b3e988388377c1cda3385bfa20c1799be101c2e12bbe3dc
# Successfully built kaggle
# ...

# %%
import opendatasets as od

# %%
dataset = 'https://www.kaggle.com/datasets/brunogrisci/brain-cancer-gene-expression-cumida'

# %%
od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sizukajm
# Your Kaggle Key: ········
# ...
# 100%|██████████| 53.4M/53.4M [00:17<00:00, 3.21MB/s]

# %%
import os

# %%
data_dir = './brain-cancer-gene-expression-cumida'

# %%
os.listdir(data_dir)
# Out:
# ['Brain_GSE50161.csv']

# %%
import pandas as pd

# %%
brain_df = pd.read_csv('Brain_GSE50.csv')
brain_df
# Out:
#      samples                   type  1007_s_at   1053_at     117_at    121_at  \
# 0        834             ependymoma  12.498150  7.604868   6.880934  9.027128
# 1        835             ependymoma  13.067436  7.998090   7.209076  9.723322
# 2        836             ependymoma  13.068179  8.573674   8.647684  9.613002
# 3        837             ependymoma  12.456040  9.098977   6.628784  8.517677
# 4        838             ependymoma  12.699958  8.800721  11.556188  9.166309
# ..       ...                    ...        ...       ...        ...       ...
# 125      959  pilocytic_astrocytoma  12.658228  8.843270   7.672655  9.125912
# 126      960  pilocytic_astrocytoma  12.812823  8.510550   8.729699  9.104402
# 127      961  pilocytic_astrocytoma  12.706991  8.795721   7.772359  8.327273
# 128      962  pilocytic_astrocytoma  12.684593  8.293938   7.228186  8.494428
# 129      963  pilocytic_astrocytoma  12.397722  8.843524   8.825100  8.551541
#
# ...
